# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasFXimenes/Alura-exercicios/blob/main/aula0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('lucas')
# Out:
# lucas

# %%
idade = 19
if idade >= 18:
  print('Autorizado para dirigir.')
elif idade < 18:
  print('Não autorizado.')
else:
  print ('Digite um valor válido')
# Out:
# Autorizado para dirigir.

# %%
'verde'
# Out:
# 'verde'

# %%
print ('Boas vindas a aula de Python')
# Out:
# Boas vindas a aula de Python

# %%
'variaveis'

# %%
nome = 'Lucas'

# %%
print(nome)
# Out:
# Lucas

# %%
cor_favorita = 'verde'

# %%
print(cor_favorita)
# Out:
# verde

# %%
print (f'nome:{nome} cor:{cor_favorita}')
# Out:
# nome:Lucas cor:verde

# %%
saldo = 5000

# %%
saldo = saldo +2000

# %%
print('Saldo disponivel: R$',saldo)
# Out:
# Saldo disponivel: R$ 14000

# %%
saldo = saldo * 2

# %%
print(saldo)
# Out:
# 14000
